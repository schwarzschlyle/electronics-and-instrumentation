# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
df = pd.read_csv('a_test.csv')

# %%
df
# Out:
#      Frequency (Hz)  Level (dB)
# 0         43.066406  -41.004822
# 1         86.132812  -37.565197
# 2        129.199219  -38.135563
# 3        172.265625  -33.101063
# 4        215.332031  -27.194887
# ..              ...         ...
# 506    21834.667970  -86.282257
# 507    21877.734380  -85.648018
# 508    21920.800780  -87.526062
# 509    21963.867190  -86.623833
# 510    22006.933590  -86.320663
#
# [511 rows x 2 columns]

# %%
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('a_train_sa.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('a_train.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('b_train.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('b_train_sa.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('b_test.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('d_train.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


df = pd.read_csv('d_train_sa.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


df = pd.read_csv('d_test.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = pd.read_csv('ee_train.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


df = pd.read_csv('ee_train_sa.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


df = pd.read_csv('ee_test.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
g_train_df = pd.read_csv('g_train.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


g_sa_df = pd.read_csv('g_train_sa.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()


g_test_df = pd.read_csv('g_test.csv')
import plotly.express as px


# Create the plot
fig = px.line(df, x='Frequency (Hz)', y='Level (dB)',log_x=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))



g_test_df = pd.read_csv('g_test.csv')
g_train_df = pd.read_csv('g_train.csv')
g_sa_df = pd.read_csv('g_train_sa.csv')


plt.plot(g_train_df['Frequency (Hz)'], g_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(g_sa_df['Frequency (Hz)'], g_sa_df['Level (dB)'], label='Train data with stochastic amplification', c = "blue")

plt.axvline(x = 147, color = 'r', linestyle = '-', label = 'D string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of D string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))



a_test_df = pd.read_csv('a_test.csv')
a_train_df = pd.read_csv('a_train.csv')
a_sa_df = pd.read_csv('a_train_sa.csv')


plt.plot(a_train_df['Frequency (Hz)'], a_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(a_sa_df['Frequency (Hz)'], a_sa_df['Level (dB)'], label='Train data with stochastic amplification', c = "blue")

plt.axvline(x = 247, color = 'r', linestyle = '-', label = 'B string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of B string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))




b_test_df = pd.read_csv('b_test.csv')
b_train_df = pd.read_csv('b_train.csv')
b_sa_df = pd.read_csv('b_train_sa.csv')


plt.plot(b_train_df['Frequency (Hz)'], b_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(b_sa_df['Frequency (Hz)'], b_sa_df['Level (dB)'], label='Train data with stochastic amplification',c = "blue")

plt.axvline(x = 110, color = 'r', linestyle = '-', label = 'A string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of A string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))




e_test_df = pd.read_csv('e_test.csv')
e_train_df = pd.read_csv('e_train.csv')
e_sa_df = pd.read_csv('e_train_sa.csv')


plt.plot(e_train_df['Frequency (Hz)'], e_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(e_sa_df['Frequency (Hz)'], e_sa_df['Level (dB)'], label='Train data with stochastic amplification', c = "blue")

plt.axvline(x = 330, color = 'r', linestyle = '-', label = 'High E string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of high E string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))



ee_test_df = pd.read_csv('ee_test.csv')
ee_train_df = pd.read_csv('ee_train.csv')
ee_sa_df = pd.read_csv('ee_train_sa.csv')


plt.plot(ee_train_df['Frequency (Hz)'], ee_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(ee_sa_df['Frequency (Hz)'], ee_sa_df['Level (dB)'], label='Train data with stochastic amplification',c = "blue")

plt.axvline(x = 82, color = 'r', linestyle = '-', label = 'Low E string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of low E string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %%
import pandas as pd
import plotly.express as px
from datetime import datetime
from google.colab import files
import io
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import seaborn as sb
import statistics 


import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10, 6))



d_test_df = pd.read_csv('d_test.csv')
d_train_df = pd.read_csv('d_train.csv')
d_sa_df = pd.read_csv('d_train_sa.csv')


plt.plot(d_train_df['Frequency (Hz)'], d_train_df['Level (dB)'], label='Train data', c = "red")
plt.plot(d_sa_df['Frequency (Hz)'], d_sa_df['Level (dB)'], label='Train data with stochastic amplification', c = "blue")

plt.axvline(x = 196, color = 'r', linestyle = '-', label = 'G string empirical frequency', c = "black")

plt.xscale('log')

plt.title("Frequency content data of G string", size=12)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.legend(loc='lower right')

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb


a_y_test = a_test_df['Level (dB)']
a_x_test = a_test_df[['Frequency (Hz)']]

a_y_train = a_train_df['Level (dB)']
a_x_train = a_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(a_x_train, a_y_train)
a_train_score = train_reg.score(a_x_test, a_y_test)
xga_a_train_pred = train_reg.predict(a_x_train)

a_y_sa = a_sa_df['Level (dB)']
a_x_sa = a_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(a_x_sa, a_y_sa)
a_sa_score = sa_reg.score(a_x_test, a_y_test)
xga_a_sa_pred = sa_reg.predict(a_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for B string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(a_test_df[['Frequency (Hz)']], a_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(a_x_train, xga_a_train_pred, c="red", label="XGB fit using train data")
plt.plot(a_x_sa, xga_a_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.plot(a_x_sa, abs(xga_a_sa_pred-xga_a_train_pred), c="black", label="Absolute difference due to schoastic amplification", linestyle = "dashed")
plt.axvline(x = 247, color = 'r', linestyle = '-', c="black", label="B string empirical frequency (247 Hz)")

plt.legend(loc='lower left')
plt.show()



print(a_train_score)
print(a_sa_score)

print(xga_a_sa_pred.argmax())
print(a_x_sa.iloc[xga_a_sa_pred.argmax()])

print(xga_a_train_pred.argmax())
print(a_x_train.iloc[xga_a_train_pred.argmax()])
# Out:
# [17:56:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:56:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.6899070612883553
# 0.3408358844548498
# 4
# Frequency (Hz)    215.332031
# Name: 4, dtype: float64
# 4
# Frequency (Hz)    215.332031
# Name: 4, dtype: float64
# 0

# %%
import xgboost as xgb


b_y_test = b_test_df['Level (dB)']
b_x_test = b_test_df[['Frequency (Hz)']]

b_y_train = b_train_df['Level (dB)']
b_x_train = b_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(b_x_train, b_y_train)
b_train_score = train_reg.score(b_x_test, b_y_test)
xgb_b_train_pred = train_reg.predict(b_x_train)

b_y_sa = b_sa_df['Level (dB)']
b_x_sa = b_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(b_x_sa, b_y_sa)
b_sa_score = sa_reg.score(b_x_test, b_y_test)
xgb_b_sa_pred = sa_reg.predict(b_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for A string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(b_test_df[['Frequency (Hz)']], b_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(b_x_train, xgb_b_train_pred, c="red", label="XGB fit using train data")
plt.plot(b_x_sa, xgb_b_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.plot(a_x_sa, abs(xgb_b_sa_pred-xgb_b_train_pred), c="black", label="Absolute difference due to schoastic amplification", linestyle = "dashed")
plt.axvline(x = 110, color = 'r', linestyle = '-', c="black", label="A string empirical frequency (110 Hz)")

plt.legend(loc='lower left')
plt.show()



print(b_train_score)

print(b_sa_score)

print(xgb_b_sa_pred.argmax())
print(b_x_sa.iloc[xgb_b_sa_pred.argmax()])

print(xgb_b_train_pred.argmax())
print(b_x_train.iloc[xgb_b_train_pred.argmax()])

print(xgb_b_sa_pred.argmax()-xgb_b_train_pred.argmax())
# Out:
# [17:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9932292917101269
# -0.028055509885409613
# 1
# Frequency (Hz)    86.132812
# Name: 1, dtype: float64
# 1
# Frequency (Hz)    86.132812
# Name: 1, dtype: float64
# 0

# %%
import xgboost as xgb


d_y_test = d_test_df['Level (dB)']
d_x_test = d_test_df[['Frequency (Hz)']]

d_y_train = d_train_df['Level (dB)']
d_x_train = d_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(d_x_train, d_y_train)
d_train_score = train_reg.score(d_x_test, d_y_test)
xgd_d_train_pred = train_reg.predict(d_x_train)

d_y_sa = d_sa_df['Level (dB)']
d_x_sa = d_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(d_x_sa, d_y_sa)
d_sa_score = sa_reg.score(d_x_test, d_y_test)
xgd_d_sa_pred = sa_reg.predict(d_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for G string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(d_test_df[['Frequency (Hz)']], d_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(d_x_train, xgd_d_train_pred, c="red", label="XGB fit using train data")
plt.plot(d_x_sa, xgd_d_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.plot(a_x_sa, abs(xgd_d_sa_pred-xgd_d_train_pred), c="black", label="Absolute difference due to schoastic amplification", linestyle = "dashed")
plt.axvline(x = 196, color = 'r', linestyle = '-', c="black", label="G string empirical frequency (196 Hz)")

plt.legend(loc='lower left')
plt.show()



print(d_train_score)

print(d_sa_score)

print(xgd_d_sa_pred.argmax())
print(d_x_sa.iloc[xgd_d_sa_pred.argmax()])

print(xgd_d_train_pred.argmax())
print(d_x_train.iloc[xgd_d_train_pred.argmax()])



print(xgd_d_sa_pred.argmax()-xgd_d_train_pred.argmax())
# Out:
# [17:56:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:56:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9591111569924629
# 0.23832708600684993
# 3
# Frequency (Hz)    172.265625
# Name: 3, dtype: float64
# 3
# Frequency (Hz)    172.265625
# Name: 3, dtype: float64
# 0

# %%
import xgboost as xgb


e_y_test = e_test_df['Level (dB)']
e_x_test = e_test_df[['Frequency (Hz)']]

e_y_train = e_train_df['Level (dB)']
e_x_train = e_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(e_x_train, e_y_train)
e_train_score = train_reg.score(e_x_test, e_y_test)
xge_e_train_pred = train_reg.predict(e_x_train)

e_y_sa = e_sa_df['Level (dB)']
e_x_sa = e_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(e_x_sa, e_y_sa)
e_sa_score = sa_reg.score(e_x_test, e_y_test)
xge_e_sa_pred = sa_reg.predict(e_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for high E string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(e_test_df[['Frequency (Hz)']], e_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(e_x_train, xge_e_train_pred, c="red", label="XGB fit using train data")
plt.plot(e_x_sa, xge_e_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.plot(a_x_sa, abs(xge_e_sa_pred-xge_e_train_pred), c="black", label="Absolute difference due to schoastic amplification", linestyle = "dashed")
plt.axvline(x = 330, color = 'r', linestyle = '-', c="black", label="High E string empirical frequency (330 Hz)")

plt.legend(loc='lower left')
plt.show()



print(e_train_score)

print(e_sa_score)



print(xge_e_sa_pred.argmax())
print(e_x_sa.iloc[xge_e_sa_pred.argmax()])

print(xge_e_train_pred.argmax())
print(e_x_train.iloc[xge_e_train_pred.argmax()])
# Out:
# [16:42:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:42:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.5737861874186783
# 0.04803694898020772
# 6
# Frequency (Hz)    301.464844
# Name: 6, dtype: float64
# 6
# Frequency (Hz)    301.464844
# Name: 6, dtype: float64

# %%
import xgboost as xgb


ee_y_test = ee_test_df['Level (dB)']
ee_x_test = ee_test_df[['Frequency (Hz)']]

ee_y_train = ee_train_df['Level (dB)']
ee_x_train = ee_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(ee_x_train, ee_y_train)
ee_train_score = train_reg.score(ee_x_test, ee_y_test)
xgee_ee_train_pred = train_reg.predict(ee_x_train)

ee_y_sa = ee_sa_df['Level (dB)']
ee_x_sa = ee_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(ee_x_sa, ee_y_sa)
ee_sa_score = sa_reg.score(ee_x_test, ee_y_test)
xgee_ee_sa_pred = sa_reg.predict(ee_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for low E string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(ee_test_df[['Frequency (Hz)']], ee_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(ee_x_train, xgee_ee_train_pred, c="red", label="XGB fit using train data")
plt.plot(ee_x_sa, xgee_ee_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.plot(ee_x_sa, abs(xgee_ee_sa_pred-xgee_ee_train_pred), c="black",
 label="Absolute difference due to schoastic amplification", linestyle = "dashed")

plt.axvline(x = 82, color = 'r', linestyle = '-', c="black", label="Low E string empirical frequency (82 Hz)")

plt.legend(loc='lower left')
plt.show()



print(ee_train_score)

print(ee_sa_score)


print(xgee_ee_sa_pred.argmax())
print(ee_x_sa.iloc[xgee_ee_sa_pred.argmax()])

print(xgee_ee_train_pred.argmax())
print(ee_x_train.iloc[xgee_ee_train_pred.argmax()])
# Out:
# [16:42:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:42:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9121560780732694
# -0.3353644881546096
# 3
# Frequency (Hz)    172.265625
# Name: 3, dtype: float64
# 3
# Frequency (Hz)    172.265625
# Name: 3, dtype: float64

# %%
import xgboost as xgb


g_y_test = g_test_df['Level (dB)']
g_x_test = g_test_df[['Frequency (Hz)']]

g_y_train = g_train_df['Level (dB)']
g_x_train = g_train_df[['Frequency (Hz)']]


train_reg = xgb.XGBRegressor().fit(g_x_train, g_y_train)
g_train_score = train_reg.score(g_x_test, g_y_test)
xgg_g_train_pred = train_reg.predict(g_x_train)

g_y_sa = g_sa_df['Level (dB)']
g_x_sa = g_sa_df[['Frequency (Hz)']]

sa_reg = xgb.XGBRegressor().fit(g_x_sa, g_y_sa)
g_sa_score = sa_reg.score(g_x_test, g_y_test)
xgg_g_sa_pred = sa_reg.predict(g_x_sa)




plt.figure(figsize=(10, 6))
plt.title("XGBoost fit for D string frequency")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Level (dB)")
plt.xscale('log')

plt.scatter(g_test_df[['Frequency (Hz)']], g_test_df['Level (dB)'], c='gray', label="Test data")
plt.plot(g_x_train, xgg_g_train_pred, c="red", label="XGB fit using train data")
plt.plot(g_x_sa, xgg_g_sa_pred, c="blue", label="XGB fit using train data with stochastic amplification")
plt.axvline(x = 147, color = 'r', linestyle = '-', c="black", label="D string empirical frequency (147 Hz)")
plt.plot(a_x_sa, abs(xgg_g_sa_pred-xgg_g_train_pred), c="black", label="Absolute difference due to schoastic amplification", linestyle = "dashed")

plt.legend(loc='lower left')
plt.show()



print(g_train_score)

print(g_sa_score)


print(xgg_g_sa_pred.argmax())
print(g_x_sa.iloc[xgg_g_sa_pred.argmax()])

print(xgg_g_train_pred.argmax())
print(g_x_train.iloc[xgg_g_train_pred.argmax()])
# Out:
# [17:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9835155643935299
# 0.1334414735059961
# 2
# Frequency (Hz)    129.199219
# Name: 2, dtype: float64
# 2
# Frequency (Hz)    129.199219
# Name: 2, dtype: float64
